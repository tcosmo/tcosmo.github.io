# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import animation, rc
from IPython.display import HTML
from som import *

# %%
fig = plt.figure()


def f(x, y):
    return np.sin(x) + np.cos(y)

img = np.zeros((40,40,3))
im = plt.imshow(img, animated=True)


def updatefig(i):
    im.set_array(inter[i])
    return im,

ani = animation.FuncAnimation(fig, updatefig, interval=400, frames=50, blit=True)

# %%
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
data = np.random.rand(3,3)
plt.figure()
for (i,d) in enumerate(data):
    plt.subplot(1,3,i+1)
    plt.imshow([[d]])
plt.show()

my_som = som(40,40,3)
inter = my_som.train(data,sigma0=20,L0=1,lam=30,stock_inter=True,pp=False)
plt.imshow(my_som.som)
plt.show()
# Out:
# t: 90
# sigma: 0.995741367357
# lr: 0.0497870683679

# %%
len(inter)
# Out:
# 91

# %%
data = np.random.rand(1000,2)

my_som = som(40,40,2)
inter = my_som.train(data,sigma0=20,L0=0.1,lam=30,stock_inter=True,pp=False)
# Out:
# t: 90
# sigma: 0.995741367357
# lr: 0.00497870683679

# %%
def get_x_y(som):
    x = []
    y = []
    for a in som:
        for b in a:
            x.append(b[0])
            y.append(b[1])
    return x,y

# %%
x,y = get_x_y(my_som)

# %%
plt.scatter(x,y)
plt.show()

# %%
fig = plt.figure()

x = []
y = []
line, = plt.plot([], [], 'bo', ms=6)
plt.xlim(0,1)
plt.ylim(0,1)

def updatefig(i):
    global x,y
    x,y = get_x_y(inter[i])
    line.set_data(x,y)
    return line,

ani = animation.FuncAnimation(fig, updatefig, interval=200, frames=90, blit=True)

# %%
HTML(ani.to_html5_video())
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
np.min(inter[0])
# Out:
# 0.00011211773200103803

# %%
import math

# %%
def PointsInCircum(r,n=1000):
    return [(math.cos(2*np.pi/n*x)*r,math.sin(2*np.pi/n*x)*r) for x in range(0,n+1)]

# %%
data = PointsInCircum(1,1000)

my_som = som(40,40,2)
inter = my_som.train(data,sigma0=20,L0=1,lam=30,stock_inter=True,pp=False,rand_f=np.random.randn)
# Out:
# t: 90
# sigma: 0.995741367357
# lr: 0.0497870683679
